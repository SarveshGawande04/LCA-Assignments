# %%
pan = input("Enter PAN number: ")

letters = tuple("ABCDEFGHIJKLMNOPQRSTUVWXYZ")
digits = tuple("0123456789")

valid = True

if len(pan) != 10:
    valid = False
else:
    for i in range(5):
        if pan[i] not in letters:
            valid = False

    for i in range(5, 9):
        if pan[i] not in digits:
            valid = False

    if pan[9] not in letters:
        valid = False

if valid:
    print("Valid PAN Number")
else:
    print("Invalid PAN Number")
# Out:
# Enter PAN number:  ABCDE1234E
# Valid PAN Number

# %%
pan = input("Enter PAN number: ")

letters = tuple("ABCDEFGHIJKLMNOPQRSTUVWXYZ")
digits = tuple("0123456789")

valid = True

if len(pan) != 10:
    valid = False
else:
    for i in range(5):
        if pan[i] not in letters:
            valid = False

    for i in range(5, 9):
        if pan[i] not in digits:
            valid = False

    if pan[9] not in letters:
        valid = False

if valid:
    print("Valid PAN Number")
else:
    print("Invalid PAN Number")
# Out:
# Enter PAN number:  ABCD1234F
# Invalid PAN Number
